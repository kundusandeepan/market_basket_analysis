# %%
import pandas as pd
import numpy as np
df2 = pd.DataFrame(np.random.rand(10, 4), columns=["a", "b", "c", "d"])

df2.plot.bar();

# %%
import numpy as np 
import matplotlib.pyplot as plt 
  
X = ['Group A','Group B','Group C','Group D']
Ygirls = [10,20,20,40]
Zboys = [20,30,25,30]
  
X_axis = np.arange(len(X))
  
plt.bar(X_axis - 0.2, Ygirls, 0.4, label = 'Girls')
plt.bar(X_axis + 0.2, Zboys, 0.4, label = 'Boys')
  
plt.xticks(X_axis, X)
plt.xlabel("Groups")
plt.ylabel("Number of Students")
plt.title("Number of Students in each group")
plt.legend()
plt.show()

# %%
# creating a DataFrame
data = {'1' : ['g', 'e', 'e'], 
        '2' : ['k', 's', 'f'], 
        '3' : ['o', 'r', 'g'], 
        '4' : ['e', 'e', 'k']}
df = pd.DataFrame(data)
print("Original DataFrame")
display(df)
  
print("Value of row 1")
display(df.iloc[1])
# Out:
# Original DataFrame
#    1  2  3  4
# 0  g  k  o  e
# 1  e  s  r  e
# 2  e  f  g  k
# Value of row 1
# 1    e
# 2    s
# 3    r
# 4    e
# Name: 1, dtype: object

# %%
df = pd.read_csv("resources1\Book2.csv")

# %%
df.head(10)
# Out:
#    month  quantity  price  total_price
# 0    jan         5     10           50
# 1    feb         6     30          180
# 2  march        10     22          220
# 3  april         7     10           70
# 4    may         8     30          240
# 5   june         3     22           66
# 6  july          1     20           20
# 7    aug         6     23          138
# 8   sept         5     10           50
# 9    oct         2     30           60

# %%
df.plot(x="quantity",y="total_price",kind="bar")
plt.show()

# %%
df = pd.read_csv("resources1\Book3.csv")
df.head(10)
# Out:
#    BillNo                          Itemname  Quantity              Date  \
# 0  539993           JUMBO BAG PINK POLKADOT        10  04.01.2011 10:00
# 1  539993                BLUE POLKADOT WRAP        25  04.01.2011 10:00
# 2  539993                RED RETROSPOT WRAP        25  04.01.2011 10:00
# 3  539993           RECYCLING BAG RETROSPOT         5  04.01.2011 10:00
# 4  539993         RED RETROSPOT SHOPPER BAG        10  04.01.2011 10:00
# 5  539993           JUMBO BAG RED RETROSPOT        10  04.01.2011 10:00
# 6  539993  RED RETROSPOT CHILDRENS UMBRELLA         6  04.01.2011 10:00
# 7  539993            JAM MAKING SET PRINTED        12  04.01.2011 10:00
# 8  539993              RECIPE BOX RETROSPOT         6  04.01.2011 10:00
# 9  539993     CHILDRENS APRON APPLES DESIGN         8  04.01.2011 10:00
#
#    Price  CustomerID         Country  Year  Month  Total_price
# 0   1.95       13313  United Kingdom  2011      1         19.5
# 1   0.42       13313  United Kingdom  2011      1         10.5
# 2   0.42       13313  United Kingdom  2011      1         10.5
# 3   2.10       13313  United Kingdom  2011      1         10.5
# 4   1.25       13313  United Kingdom  2011      1         12.5
# 5   1.95       13313  United Kingdom  2011      1         19.5
# 6   3.25       13313  United Kingdom  2011      1         19.5
# 7   1.45       13313  United Kingdom  2011      1         17.4
# 8   2.95       13313  United Kingdom  2011      1         17.7
# 9   1.95       13313  United Kingdom  2011      1         15.6

# %%
df.plot(x="Month",y=["Total_price","Quantity"],kind="bar")
plt.show()
