# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Dependencies and Setup
import pandas as pd

# %%
# File to Load 
data_df = pd.read_csv("resources1\storedata.csv",sep=';')
# Out:
# C:\Users\Sandeepan Kundu\AppData\Local\Temp\ipykernel_12612\2237121939.py:2: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_df = pd.read_csv("resources1\storedata.csv",sep=';')

# %%
#check dataframe
data_df.head(10)
# Out:
#    BillNo                             Itemname  Quantity              Date  \
# 0  536365   WHITE HANGING HEART T-LIGHT HOLDER         6  01.12.2010 08:26
# 1  536365                  WHITE METAL LANTERN         6  01.12.2010 08:26
# 2  536365       CREAM CUPID HEARTS COAT HANGER         8  01.12.2010 08:26
# 3  536365  KNITTED UNION FLAG HOT WATER BOTTLE         6  01.12.2010 08:26
# 4  536365       RED WOOLLY HOTTIE WHITE HEART.         6  01.12.2010 08:26
# 5  536365         SET 7 BABUSHKA NESTING BOXES         2  01.12.2010 08:26
# 6  536365    GLASS STAR FROSTED T-LIGHT HOLDER         6  01.12.2010 08:26
# 7  536366               HAND WARMER UNION JACK         6  01.12.2010 08:28
# 8  536366            HAND WARMER RED POLKA DOT         6  01.12.2010 08:28
# 9  536367        ASSORTED COLOUR BIRD ORNAMENT        32  01.12.2010 08:34
#
#   Price  CustomerID         Country
# 0  2,55     17850.0  United Kingdom
# 1  3,39     17850.0  United Kingdom
# ...

# %%
# View Summary statisctics
print (data_df.describe())
# Out:
#             Quantity     CustomerID
# count  522064.000000  388023.000000
# mean       10.090435   15316.931710
# std       161.110525    1721.846964
# min     -9600.000000   12346.000000
# 25%         1.000000   13950.000000
# 50%         3.000000   15265.000000
# 75%        10.000000   16837.000000
# max     80995.000000   18287.000000

# %%
# List of column names
print(data_df.columns)
# Out:
# Index(['BillNo', 'Itemname', 'Quantity', 'Date', 'Price', 'CustomerID',
#        'Country'],
#       dtype='object')

# %%
# To count total rows 
print(data_df.shape)
# Out:
# (522064, 7)

# %%
# To find the types of data 
print (data_df.dtypes)
# Out:
# BillNo         object
# Itemname       object
# Quantity        int64
# Date           object
# Price          object
# CustomerID    float64
# Country        object
# dtype: object

# %%
# To find out the types of all columns in the dataframe
print(data_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 522064 entries, 0 to 522063
# Data columns (total 7 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   BillNo      522064 non-null  object
#  1   Itemname    520609 non-null  object
#  2   Quantity    522064 non-null  int64
#  3   Date        522064 non-null  object
#  4   Price       522064 non-null  object
#  5   CustomerID  388023 non-null  float64
#  6   Country     522064 non-null  object
# dtypes: float64(1), int64(1), object(5)
# memory usage: 27.9+ MB
# None

# %%
# To count missing values in each column
print(data_df.isnull().sum())
# Out:
# BillNo             0
# Itemname        1455
# Quantity           0
# Date               0
# Price              0
# CustomerID    134041
# Country            0
# dtype: int64

# %%
# To drop missing values 
data_df=data_df.drop_duplicates()

# %%
# To count missing values in each column
print(data_df.isnull().sum())
# Out:
# BillNo             0
# Itemname        1455
# Quantity           0
# Date               0
# Price              0
# CustomerID    133967
# Country            0
# dtype: int64

# %%
# To Drop data with negative or zero quantity
data_df=data_df.loc[data_df['Quantity']>0]

# %%
# To count missing values in each column
print(data_df.isnull().sum())
# Out:
# BillNo             0
# Itemname         592
# Quantity           0
# Date               0
# Price              0
# CustomerID    132631
# Country            0
# dtype: int64

# %%
# to Drop data with zero price
data_df=data_df.loc[data_df['Price']>'0']

# %%
# To count missing values in each column
print(data_df.isnull().sum())
# Out:
# BillNo             0
# Itemname           0
# Quantity           0
# Date               0
# Price              0
# CustomerID    131497
# Country            0
# dtype: int64

# %%
#Filling null data
data_df=data_df.fillna('-')

# %%
# To count missing values in each column
print(data_df.isnull().sum())
# Out:
# BillNo        0
# Itemname      0
# Quantity      0
# Date          0
# Price         0
# CustomerID    0
# Country       0
# dtype: int64

# %%
# Splitting data into year and month
data_df['Year']=data_df['Date'].apply(lambda x:x.split('.')[2])
data_df['Year']=data_df['Year'].apply(lambda x:x.split(' ')[0])
data_df['Month']=data_df['Date'].apply(lambda x:x.split('.')[1])
data_df.head()
# Out:
#    BillNo                             Itemname  Quantity              Date  \
# 0  536365   WHITE HANGING HEART T-LIGHT HOLDER         6  01.12.2010 08:26
# 1  536365                  WHITE METAL LANTERN         6  01.12.2010 08:26
# 2  536365       CREAM CUPID HEARTS COAT HANGER         8  01.12.2010 08:26
# 3  536365  KNITTED UNION FLAG HOT WATER BOTTLE         6  01.12.2010 08:26
# 4  536365       RED WOOLLY HOTTIE WHITE HEART.         6  01.12.2010 08:26
#
#   Price CustomerID         Country  Year Month
# 0  2,55    17850.0  United Kingdom  2010    12
# 1  3,39    17850.0  United Kingdom  2010    12
# 2  2,75    17850.0  United Kingdom  2010    12
# 3  3,39    17850.0  United Kingdom  2010    12
# 4  3,39    17850.0  United Kingdom  2010    12

# %%
# Creating a 'Total price' column
data_df['Price']=data_df['Price'].str.replace(',','.').astype('float64')
data_df['Total_price']=data_df.Quantity*data_df.Price
data_df.head()
# Out:
#    BillNo                             Itemname  Quantity              Date  \
# 0  536365   WHITE HANGING HEART T-LIGHT HOLDER         6  01.12.2010 08:26
# 1  536365                  WHITE METAL LANTERN         6  01.12.2010 08:26
# 2  536365       CREAM CUPID HEARTS COAT HANGER         8  01.12.2010 08:26
# 3  536365  KNITTED UNION FLAG HOT WATER BOTTLE         6  01.12.2010 08:26
# 4  536365       RED WOOLLY HOTTIE WHITE HEART.         6  01.12.2010 08:26
#
#    Price CustomerID         Country  Year Month  Total_price
# 0   2.55    17850.0  United Kingdom  2010    12        15.30
# 1   3.39    17850.0  United Kingdom  2010    12        20.34
# 2   2.75    17850.0  United Kingdom  2010    12        22.00
# 3   3.39    17850.0  United Kingdom  2010    12        20.34
# 4   3.39    17850.0  United Kingdom  2010    12        20.34

# %%
# Checking the total price in each month
data_df.groupby(['Year','Month'])['Total_price'].sum()
# Out:
# Year  Month
# 2010  12        807215.780
# 2011  01        665727.010
#       02        503060.520
#       03        679471.260
#       04        527214.751
#       05        749008.990
#       06        727311.200
#       07        669497.001
#       08        732944.090
#       09       1006294.612
#       10       1115378.190
#       11       1465421.650
#       12        628846.920
# Name: Total_price, dtype: float64

# %%
# droping 2010 data
data_df=data_df.loc[data_df['Year']!='2010']

# %%
# Checking the total price in each month
data_df.groupby(['Year','Month'])['Total_price'].sum()
# Out:
# Year  Month
# 2011  01        665727.010
#       02        503060.520
#       03        679471.260
#       04        527214.751
#       05        749008.990
#       06        727311.200
#       07        669497.001
#       08        732944.090
#       09       1006294.612
#       10       1115378.190
#       11       1465421.650
#       12        628846.920
# Name: Total_price, dtype: float64

# %%
# Save DataFrame to a new CSV file
data_df.to_csv('Resources1\cleaneddata.csv', index=False)

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# File to Load 
data_df = pd.read_csv("Resources1\cleaneddata1.csv")
data_df.head(10)
# Out:
# C:\Users\Sandeepan Kundu\AppData\Local\Temp\ipykernel_12612\186947227.py:2: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_df = pd.read_csv("Resources1\cleaneddata1.csv")
#    BillNo                          Itemname  Quantity              Date  \
# 0  539993           JUMBO BAG PINK POLKADOT        10  04.01.2011 10:00
# 1  539993                BLUE POLKADOT WRAP        25  04.01.2011 10:00
# 2  539993                RED RETROSPOT WRAP        25  04.01.2011 10:00
# 3  539993           RECYCLING BAG RETROSPOT         5  04.01.2011 10:00
# 4  539993         RED RETROSPOT SHOPPER BAG        10  04.01.2011 10:00
# 5  539993           JUMBO BAG RED RETROSPOT        10  04.01.2011 10:00
# 6  539993  RED RETROSPOT CHILDRENS UMBRELLA         6  04.01.2011 10:00
# 7  539993            JAM MAKING SET PRINTED        12  04.01.2011 10:00
# 8  539993              RECIPE BOX RETROSPOT         6  04.01.2011 10:00
# ...

# %%
# Import dependencies.
import matplotlib.pyplot as plt

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import dependencies.
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt

# %%
#creating subset data frame 
df2 = data_df[['Month', 'Quantity', "Total_price"]].copy()
df2
# Out:
#         Month  Quantity  Total_price
# 0           1        10        19.50
# 1           1        25        10.50
# 2           1        25        10.50
# 3           1         5        10.50
# 4           1        10        12.50
# ...       ...       ...          ...
# 473800     12        12        10.20
# 473801     12         6        12.60
# 473802     12         4        16.60
# 473803     12         4        16.60
# 473804     12         3        14.85
#
# [473805 rows x 3 columns]

# %%
# filter /group by month 
df3=df2.groupby(['Month']).sum()
df3
# Out:
#        Quantity  Total_price
# Month
# 1        377045   665727.010
# 2        273125   503060.520
# 3        360383   679471.260
# 4        302863   527214.751
# 5        385843   749008.990
# 6        371487   727311.200
# 7        374701   669497.001
# 8        407850   732944.090
# 9        543655  1006294.612
# 10       600005  1115378.190
# 11       731086  1465421.650
# 12       308906   628846.920

# %%
# to reset the indexing 
df4 = df3.reset_index()
df4
# Out:
#     Month  Quantity  Total_price
# 0       1    377045   665727.010
# 1       2    273125   503060.520
# 2       3    360383   679471.260
# 3       4    302863   527214.751
# 4       5    385843   749008.990
# 5       6    371487   727311.200
# 6       7    374701   669497.001
# 7       8    407850   732944.090
# 8       9    543655  1006294.612
# 9      10    600005  1115378.190
# 10     11    731086  1465421.650
# 11     12    308906   628846.920

# %%
df4.plot(x="Month", y=["Quantity","Total_price"],kind="bar")
# Out:
# <Axes: xlabel='Month'>

# %%
#creating subset data frame 
df5 = data_df[['Month', 'Country', "Total_price"]].copy()
df5
# Out:
#         Month        Country  Total_price
# 0           1  UnitedKingdom        19.50
# 1           1  UnitedKingdom        10.50
# 2           1  UnitedKingdom        10.50
# 3           1  UnitedKingdom        10.50
# 4           1  UnitedKingdom        12.50
# ...       ...            ...          ...
# 473800     12         France        10.20
# 473801     12         France        12.60
# 473802     12         France        16.60
# 473803     12         France        16.60
# 473804     12         France        14.85
#
# [473805 rows x 3 columns]

# %%
# filter /group by month 
df6=df5.groupby(["Month","Country"]).sum()
df6
# Out:
#                      Total_price
# Month Country
# 1     Australia          9017.71
#       Belgium            1200.20
#       France            17740.12
#       Germany           16880.84
#       Greece             2661.24
# ...                          ...
# 12    Portugal           2808.19
#       Spain               316.21
#       Sweden              238.00
#       USA                 885.24
#       UnitedKingdom    591617.28
#
# [218 rows x 1 columns]

# %%
# to reset the indexing 
df7 = df6.reset_index()
df7
# Out:
#      Month        Country  Total_price
# 0        1      Australia      9017.71
# 1        1        Belgium      1200.20
# 2        1         France     17740.12
# 3        1        Germany     16880.84
# 4        1         Greece      2661.24
# ..     ...            ...          ...
# 213     12       Portugal      2808.19
# 214     12          Spain       316.21
# 215     12         Sweden       238.00
# 216     12            USA       885.24
# 217     12  UnitedKingdom    591617.28
#
# [218 rows x 3 columns]

# %%
df9=df5.pivot_table(index='Month',columns='Country',values='Total_price')
df9
# Out:
# Country   Australia    Austria    Bahrain    Belgium   Brazil     France  \
# Month
# 1         71.005591        NaN        NaN  20.693103      NaN  26.878970
# 2        165.117079  24.683810        NaN  18.641624      NaN  20.324487
# 3        159.481389  94.895556        NaN  20.819752      NaN  26.859945
# 4         42.866667  26.183846        NaN  17.150690  35.7375  24.467301
# 5        117.572500  24.498627  32.258824  18.587755      NaN  24.385706
# 6        149.040059        NaN        NaN  18.586174      NaN  27.709169
# 7         31.222516  21.671818        NaN  19.340391      NaN  22.321853
# 8        210.179439  17.228182        NaN  18.319691      NaN  24.272337
# 9         50.065980        NaN        NaN  22.869674      NaN  22.570366
# 10       150.443246  19.329259        NaN  21.535530      NaN  37.992111
# 11       176.651707  18.996857        NaN  25.990782      NaN  20.608823
# 12              NaN  97.600000        NaN  15.082234      NaN  22.459630
#
# ...

# %%
df10=df9.fillna(0)
df10
# Out:
# Country   Australia    Austria    Bahrain    Belgium   Brazil     France  \
# Month
# 1         71.005591   0.000000   0.000000  20.693103   0.0000  26.878970
# 2        165.117079  24.683810   0.000000  18.641624   0.0000  20.324487
# 3        159.481389  94.895556   0.000000  20.819752   0.0000  26.859945
# 4         42.866667  26.183846   0.000000  17.150690  35.7375  24.467301
# 5        117.572500  24.498627  32.258824  18.587755   0.0000  24.385706
# 6        149.040059   0.000000   0.000000  18.586174   0.0000  27.709169
# 7         31.222516  21.671818   0.000000  19.340391   0.0000  22.321853
# 8        210.179439  17.228182   0.000000  18.319691   0.0000  24.272337
# 9         50.065980   0.000000   0.000000  22.869674   0.0000  22.570366
# 10       150.443246  19.329259   0.000000  21.535530   0.0000  37.992111
# 11       176.651707  18.996857   0.000000  25.990782   0.0000  20.608823
# 12         0.000000  97.600000   0.000000  15.082234   0.0000  22.459630
#
# ...

# %%
# Creating a 'Sales' column
df10.insert(loc=1, column="Country", value=df10.sum())
df10
# Out:
# Country   Australia  Country    Austria    Bahrain    Belgium   Brazil  \
# Month
# 1         71.005591      NaN   0.000000   0.000000  20.693103   0.0000
# 2        165.117079      NaN  24.683810   0.000000  18.641624   0.0000
# 3        159.481389      NaN  94.895556   0.000000  20.819752   0.0000
# 4         42.866667      NaN  26.183846   0.000000  17.150690  35.7375
# 5        117.572500      NaN  24.498627  32.258824  18.587755   0.0000
# 6        149.040059      NaN   0.000000   0.000000  18.586174   0.0000
# 7         31.222516      NaN  21.671818   0.000000  19.340391   0.0000
# 8        210.179439      NaN  17.228182   0.000000  18.319691   0.0000
# 9         50.065980      NaN   0.000000   0.000000  22.869674   0.0000
# 10       150.443246      NaN  19.329259   0.000000  21.535530   0.0000
# 11       176.651707      NaN  18.996857   0.000000  25.990782   0.0000
# 12         0.000000      NaN  97.600000   0.000000  15.082234   0.0000
#
# ...

# %%
del df10['Country']
df10
# Out:
# Country   Australia    Austria    Bahrain    Belgium   Brazil     France  \
# Month
# 1         71.005591   0.000000   0.000000  20.693103   0.0000  26.878970
# 2        165.117079  24.683810   0.000000  18.641624   0.0000  20.324487
# 3        159.481389  94.895556   0.000000  20.819752   0.0000  26.859945
# 4         42.866667  26.183846   0.000000  17.150690  35.7375  24.467301
# 5        117.572500  24.498627  32.258824  18.587755   0.0000  24.385706
# 6        149.040059   0.000000   0.000000  18.586174   0.0000  27.709169
# 7         31.222516  21.671818   0.000000  19.340391   0.0000  22.321853
# 8        210.179439  17.228182   0.000000  18.319691   0.0000  24.272337
# 9         50.065980   0.000000   0.000000  22.869674   0.0000  22.570366
# 10       150.443246  19.329259   0.000000  21.535530   0.0000  37.992111
# 11       176.651707  18.996857   0.000000  25.990782   0.0000  20.608823
# 12         0.000000  97.600000   0.000000  15.082234   0.0000  22.459630
#
# ...

# %%
# to reset the indexing 
df11 = df10.reset_index()
df11
# Out:
# Country  Month   Australia    Austria    Bahrain    Belgium   Brazil  \
# 0            1   71.005591   0.000000   0.000000  20.693103   0.0000
# 1            2  165.117079  24.683810   0.000000  18.641624   0.0000
# 2            3  159.481389  94.895556   0.000000  20.819752   0.0000
# 3            4   42.866667  26.183846   0.000000  17.150690  35.7375
# 4            5  117.572500  24.498627  32.258824  18.587755   0.0000
# 5            6  149.040059   0.000000   0.000000  18.586174   0.0000
# 6            7   31.222516  21.671818   0.000000  19.340391   0.0000
# 7            8  210.179439  17.228182   0.000000  18.319691   0.0000
# 8            9   50.065980   0.000000   0.000000  22.869674   0.0000
# 9           10  150.443246  19.329259   0.000000  21.535530   0.0000
# 10          11  176.651707  18.996857   0.000000  25.990782   0.0000
# 11          12    0.000000  97.600000   0.000000  15.082234   0.0000
#
# ...

# %%
# Save DataFrame to a new CSV file
df11.to_csv('Resources1\df11.csv', index=False)

# %%
#Month=df10['Month']
#Sales=df10['Sales']
Australia=df11['Australia']
Austria=df11['Austria']
Bahrain=df11['Bahrain']
Belgium=df11['Belgium']
Brazil=df11['Brazil']
France=df11['France']
Germany=df11['Germany']
Greece=df11['Greece']
HongKong=df11['HongKong']
Iceland=df11['Iceland']
RSA=df11['RSA']
SaudiArabia=df11['SaudiArabia']
Singapore=df11['Singapore']
Spain=df11['Spain']
Sweden=df11['Sweden']
Switzerland=df11['Switzerland']
USA=df11['USA']
UnitedArabEmirates=df11['UnitedArabEmirates']
UnitedKingdom=df11['UnitedKingdom']
Unspecified=df11['Unspecified']

dflist = ['Australia','Austria','Bahrain','Belgium','Brazil','France','Germany','Greece','HongKong','Iceland','RSA','SaudiArabia','Singapore','Spain','Sweden','Switzerland','USA','UnitedArabEmirates','UnitedKingdom','Unspecified']
df11['result']=df11[dflist].sum(axis=1)
df11
# Out:
# Country  Month   Australia    Austria    Bahrain    Belgium   Brazil  \
# 0            1   71.005591   0.000000   0.000000  20.693103   0.0000
# 1            2  165.117079  24.683810   0.000000  18.641624   0.0000
# 2            3  159.481389  94.895556   0.000000  20.819752   0.0000
# 3            4   42.866667  26.183846   0.000000  17.150690  35.7375
# 4            5  117.572500  24.498627  32.258824  18.587755   0.0000
# 5            6  149.040059   0.000000   0.000000  18.586174   0.0000
# 6            7   31.222516  21.671818   0.000000  19.340391   0.0000
# 7            8  210.179439  17.228182   0.000000  18.319691   0.0000
# 8            9   50.065980   0.000000   0.000000  22.869674   0.0000
# 9           10  150.443246  19.329259   0.000000  21.535530   0.0000
# 10          11  176.651707  18.996857   0.000000  25.990782   0.0000
# 11          12    0.000000  97.600000   0.000000  15.082234   0.0000
#
# ...

# %%
#df10.plot('Month',Australia,kind='bar')
month=df11['Month']
sales=df11['result']
Australia=df11['Australia']
Austria=df11['Austria']
Bahrain=df11['Bahrain']
Belgium=df11['Belgium']
Brazil=df11['Brazil']
France=df11['France']
Germany=df11['Germany']
Greece=df11['Greece']
HongKong=df11['HongKong']
Iceland=df11['Iceland']
RSA=df11['RSA']
SaudiArabia=df11['SaudiArabia']
Singapore=df11['Singapore']
Spain=df11['Spain']
Sweden=df11['Sweden']
Switzerland=df11['Switzerland']
USA=df11['USA']
UnitedArabEmirates=df11['UnitedArabEmirates']
UnitedKingdom=df11['UnitedKingdom']
Unspecified=df11['Unspecified']

# %%
plt.bar(month,Australia)
plt.bar(month,Austria,bottom=Australia)
plt.bar(month,Bahrain,bottom=Australia+Austria)
plt.bar(month,Belgium,bottom=Australia+Austria+Bahrain)
plt.bar(month,Brazil,bottom=Australia+Austria+Bahrain+Belgium)
plt.bar(month,France,bottom=Australia+Austria+Bahrain+Belgium+Brazil)
plt.bar(month,Germany,bottom=Australia+Austria+Bahrain+Belgium+Brazil+France)
plt.bar(month,Greece,bottom=Australia+Austria+Bahrain+Belgium+Brazil+France+Germany)
plt.bar(month,HongKong,bottom=Australia+Austria+Bahrain+Belgium+Brazil+France+Germany+Greece)
plt.bar(month,Iceland,bottom=Australia+Austria+Bahrain+Belgium+Brazil+France+Germany+Greece+HongKong)
plt.bar(month,RSA,bottom=Australia+Austria+Bahrain+Belgium+Brazil+France+Germany+Greece+HongKong+Iceland)
plt.bar(month,SaudiArabia,bottom=Australia+Austria+Bahrain+Belgium+Brazil+France+Germany+Greece+HongKong+Iceland+RSA)
plt.bar(month,Singapore,bottom=Australia+Austria+Bahrain+Belgium+Brazil+France+Germany+Greece+HongKong+Iceland+RSA+SaudiArabia)
plt.bar(month,Spain,bottom=Australia+Austria+Bahrain+Belgium+Brazil+France+Germany+Greece+HongKong+Iceland+RSA+SaudiArabia+Singapore)
plt.bar(month,Sweden,bottom=Australia+Austria+Bahrain+Belgium+Brazil+France+Germany+Greece+HongKong+Iceland+RSA+SaudiArabia+Singapore+Spain)
plt.bar(month,Switzerland,bottom=Australia+Austria+Bahrain+Belgium+Brazil+France+Germany+Greece+HongKong+Iceland+RSA+SaudiArabia+Singapore+Spain+Sweden)
plt.bar(month,USA,bottom=Australia+Austria+Bahrain+Belgium+Brazil+France+Germany+Greece+HongKong+Iceland+RSA+SaudiArabia+Singapore+Spain+Sweden+Switzerland)
plt.bar(month,UnitedArabEmirates,bottom=Australia+Austria+Bahrain+Belgium+Brazil+France+Germany+Greece+HongKong+Iceland+RSA+SaudiArabia+Singapore+Spain+Sweden+Switzerland+USA)
plt.bar(month,UnitedKingdom,bottom=Australia+Austria+Bahrain+Belgium+Brazil+France+Germany+Greece+HongKong+Iceland+RSA+SaudiArabia+Singapore+Spain+Sweden+Switzerland+USA+UnitedArabEmirates)
plt.bar(month,Unspecified,bottom=Australia+Austria+Bahrain+Belgium+Brazil+France+Germany+Greece+HongKong+Iceland+RSA+SaudiArabia+Singapore+Spain+Sweden+Switzerland+USA+UnitedArabEmirates+UnitedKingdom)
plt.xlabel("Month")
plt.ylabel("sales")
plt.legend(dflist)
